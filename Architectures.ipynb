# %%
## Own Imp 1

from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F

use_cuda = torch.cuda.is_available()


class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()




        #Constants for the Convolution layer
        self.n_filters = 16
        self.conv_even_kernel = 3
        self.conv_even_kernel1 = 5
        self.conv_even_padding = 1
        self.conv_even_padding1 = 3
        self.conv_even_padding2_1 = 2
        

        self.conv_stride = 1
        self.conv_stride1 = 2

        self.n_filters2 = 32

        self.n_filters3 = 128

        self.n_filters4 = 512


        

        #Constants for the dense layer
        self.n_units = 512


        #Layers
        self.conv = nn.Conv2d(in_channels=3,
                           out_channels=self.n_filters,
                           kernel_size=self.conv_even_kernel1,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding1)
  
        
        self.conv2 = nn.Conv2d(in_channels=self.n_filters,
                           out_channels=self.n_filters2,
                           kernel_size=self.conv_even_kernel,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding)
  
        self.conv2_1 = nn.Conv2d(in_channels=self.n_filters2,
                           out_channels=self.n_filters2,
                           kernel_size=self.conv_even_kernel,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding2_1)
        
        self.conv3 = nn.Conv2d(in_channels=self.n_filters2,
                           out_channels=self.n_filters3,
                           kernel_size=self.conv_even_kernel,
                           stride=self.conv_stride1,
                           padding=self.conv_even_padding)
        
        self.conv4 = nn.Conv2d(in_channels=self.n_filters3,
                           out_channels=self.n_filters4,
                           kernel_size=self.conv_even_kernel,
                           stride=self.conv_stride1,
                           padding=self.conv_even_padding)



    def forward(self, x):
       # print(x.shape)
        x = self.conv(x)
       # print(x.shape)
        x = F.relu(x)
        x = self.conv2(x)
      #  print(x.shape)
        x = F.relu(x)
        x = self.conv2_1(x)
      #  print(x.shape)
        x = F.relu(x)
        
        x = F.max_pool2d(x, 3, 2)
      #  print(x.shape)
        x = F.relu(x)
        x = self.conv3(x)
      #  print(x.shape)
        
        x = F.relu(x)
        x = F.max_pool2d(x, 3, 2)
       # print(x.shape)
        x = F.relu(x)
        #Resize for the dense 
        x = self.conv4(x)
        #print(x.shape)
        
        x = F.relu(x)
        #x = F.max_pool2d(x, 3, 2)
        #x = F.max_pool2d(x, 2, 2)
        #print(x.shape)
        x = F.relu(x)
        

        return x


feature_mapping = Net()
if use_cuda:
    feature_mapping.cuda()
print(feature_mapping)

# %%
## Own Imp 2

from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F

use_cuda = torch.cuda.is_available()



class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
      



        #Constants for the Convolution layer
        self.n_filters = 16
        self.conv_even_kernel = 3
        self.conv_even_kernel1 = 5
        self.conv_even_padding_1 = 1
        self.conv_even_padding_0 = 0
        self.conv_even_padding_2 = 2
        

        self.conv_stride = 1
        self.conv_stride1 = 2

        self.n_filters2 = 32

        self.n_filters3 = 128

        self.n_filters4 = 256

        self.n_filters5 = 512


        

        #Constants for the dense layer
        self.n_units = 512
      

        #Layers
        self.conv = nn.Conv2d(in_channels=3,
                           out_channels=self.n_filters,
                           kernel_size=self.conv_even_kernel1,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding_2)
  
        
        self.conv2 = nn.Conv2d(in_channels=self.n_filters,
                           out_channels=self.n_filters2,
                           kernel_size=self.conv_even_kernel,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding_2)
        self.conv22 = nn.Conv2d(in_channels=self.n_filters2,
                           out_channels=self.n_filters2,
                           kernel_size=self.conv_even_kernel,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding_2)
        


        self.conv3 = nn.Conv2d(in_channels=self.n_filters2,
                           out_channels=self.n_filters3,
                           kernel_size=self.conv_even_kernel,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding_2)
        
        self.conv33 = nn.Conv2d(in_channels=self.n_filters3,
                           out_channels=self.n_filters3,
                           kernel_size=self.conv_even_kernel,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding_2)
        
        self.conv4 = nn.Conv2d(in_channels=self.n_filters3,
                           out_channels=self.n_filters4,
                           kernel_size=self.conv_even_kernel,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding_1)
        
        self.conv5 = nn.Conv2d(in_channels=self.n_filters4,
                           out_channels=self.n_filters5,
                           kernel_size=self.conv_even_kernel,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding_2)



    def forward(self, x):
       # print(x.shape)
        x = self.conv(x)
       # print(x.shape)
        x = F.relu(x)
        x = self.conv2(x)
        x = F.relu(x)
        x = self.conv22(x)
      #  print(x.shape)
        
        x = F.max_pool2d(x, 3, 2)
      #  print(x.shape)
        x = F.relu(x)
        x = self.conv3(x)
    
      #  print(x.shape)
        
        x = F.relu(x)
        x = F.max_pool2d(x, 3, 2)
       # print(x.shape)
        x = F.relu(x)
        #Resize for the dense 
        x = self.conv4(x)
        #print(x.shape)
        
        x = F.relu(x)

        x = F.max_pool2d(x, 3, 2)

        x = self.conv5(x)

        x = F.relu(x)

        x = F.max_pool2d(x, 3, 2)


        return x



feature_mapping = Net()
if use_cuda:
    feature_mapping.cuda()
print(feature_mapping)

# %%
## Own Imp 3

from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F

use_cuda = torch.cuda.is_available()

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()



        #Constants for the Convolution layer
        self.n_filters = 8
        self.conv_even_kernel = 3
        self.conv_even_kernel1 = 5
        self.conv_even_padding_0 = 0
        self.conv_even_padding_1 = 1
        self.conv_even_padding_2 = 2

        

        self.conv_stride = 1
        self.conv_stride1 = 2

        self.n_filters2 = 16

        self.n_filters3 = 32

        self.n_filters4 = 128

        self.n_filters5 = 256

        

        self.n_filters6 = 512


        

        #Constants for the dense layer
        self.n_units = 512
   

        #Layers
        self.conv = nn.Conv2d(in_channels=3,
                           out_channels=self.n_filters,
                           kernel_size=self.conv_even_kernel1,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding_2)
  
        
        self.conv2 = nn.Conv2d(in_channels=self.n_filters,
                           out_channels=self.n_filters2,
                           kernel_size=self.conv_even_kernel,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding_2)
        self.conv22 = nn.Conv2d(in_channels=self.n_filters2,
                           out_channels=self.n_filters2,
                           kernel_size=self.conv_even_kernel,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding_2)
        


        self.conv3 = nn.Conv2d(in_channels=self.n_filters2,
                           out_channels=self.n_filters3,
                           kernel_size=self.conv_even_kernel,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding_2)
        
        
        self.conv4 = nn.Conv2d(in_channels=self.n_filters3,
                           out_channels=self.n_filters4,
                           kernel_size=self.conv_even_kernel,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding_1)
        
        self.conv5 = nn.Conv2d(in_channels=self.n_filters4,
                           out_channels=self.n_filters5,
                           kernel_size=self.conv_even_kernel,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding_2)
        
        self.conv6 = nn.Conv2d(in_channels=self.n_filters5,
                           out_channels=self.n_filters6,
                           kernel_size=self.conv_even_kernel,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding_1)



    def forward(self, x):
       # print(x.shape)
        x = self.conv(x)
       # print(x.shape)
        x = F.relu(x)
        x = self.conv2(x)
        x = F.relu(x)
        x = self.conv22(x)
      #  print(x.shape)
        
        x = F.max_pool2d(x, 3, 2)
      #  print(x.shape)
        x = F.relu(x)
        x = self.conv3(x)
    
      #  print(x.shape)
        
        x = F.relu(x)
        x = F.max_pool2d(x, 3, 2)
       # print(x.shape)
        x = F.relu(x)
        #Resize for the dense 
        x = self.conv4(x)
        #print(x.shape)
        
        x = F.relu(x)

        x = F.max_pool2d(x, 3, 2)

        x = self.conv5(x)

        x = F.relu(x)

        x = F.max_pool2d(x, 3, 2)
      
        x = self.conv6(x)

        x = F.relu(x)

        return x



feature_mapping = Net()
if use_cuda:
    feature_mapping.cuda()
print(feature_mapping)

# %%
## Own Imp 4

from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F

use_cuda = torch.cuda.is_available()

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()

        


        #Constants for the Convolution layer
        self.n_filters = 8
        self.conv_even_kernel = 3
        self.conv_even_kernel1 = 5
        self.conv_even_padding_1 = 1
        self.conv_even_padding_2 = 2
        

        self.conv_stride = 1
        self.conv_stride1 = 2

        self.n_filters2 = 16

        self.n_filters3 = 32

        self.n_filters4 = 128

        self.n_filters5 = 256

        

        self.n_filters6 = 512


        

        #Constants for the dense layer
        self.n_units = 512


        #Layers
        self.conv = nn.Conv2d(in_channels=3,
                           out_channels=self.n_filters,
                           kernel_size=self.conv_even_kernel1,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding_2)
  
        
        self.conv2 = nn.Conv2d(in_channels=self.n_filters,
                           out_channels=self.n_filters2,
                           kernel_size=self.conv_even_kernel,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding_2)
   
        


        self.conv3 = nn.Conv2d(in_channels=self.n_filters2,
                           out_channels=self.n_filters3,
                           kernel_size=self.conv_even_kernel,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding_2)
        self.conv33 = nn.Conv2d(in_channels=self.n_filters3,
                           out_channels=self.n_filters3,
                           kernel_size=self.conv_even_kernel,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding_2)
        
        
        self.conv4 = nn.Conv2d(in_channels=self.n_filters3,
                           out_channels=self.n_filters4,
                           kernel_size=self.conv_even_kernel,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding_1)
        
        self.conv44 = nn.Conv2d(in_channels=self.n_filters4,
                           out_channels=self.n_filters4,
                           kernel_size=self.conv_even_kernel,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding_1)
        
        self.conv5 = nn.Conv2d(in_channels=self.n_filters4,
                           out_channels=self.n_filters5,
                           kernel_size=self.conv_even_kernel,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding_2)
        
        self.conv6 = nn.Conv2d(in_channels=self.n_filters5,
                           out_channels=self.n_filters6,
                           kernel_size=self.conv_even_kernel,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding_2)



    def forward(self, x):
       # print(x.shape)
        x = self.conv(x)
       # print(x.shape)
        x = F.relu(x)
        x = self.conv2(x)
        x = F.relu(x)
      #  print(x.shape)
        
        x = F.max_pool2d(x, 3, 2)
      #  print(x.shape)
        x = F.relu(x)
        x = self.conv3(x)
        x = F.relu(x)
        x = self.conv33(x)
    
      #  print(x.shape)
        
        x = F.relu(x)
        x = F.max_pool2d(x, 3, 2)
       # print(x.shape)
        x = F.relu(x)
        #Resize for the dense 
        x = self.conv4(x)
        #print(x.shape)
        
        x = F.relu(x)

        x = self.conv44(x)
        #print(x.shape)
        
        x = F.relu(x)

        x = F.max_pool2d(x, 3, 2)

        x = self.conv5(x)

        x = F.relu(x)

        x = F.max_pool2d(x, 3, 2)
      
        x = self.conv6(x)

        x = F.relu(x)



        return x



feature_mapping = Net()
if use_cuda:
    feature_mapping.cuda()
print(feature_mapping)

# %%
## Own Imp 5

from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F

use_cuda = torch.cuda.is_available()

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()



        #Constants for the Convolution layer
        self.n_filters = 8
        self.conv_even_kernel = 3
        self.conv_even_kernel1 = 5
        self.conv_even_padding_0 = 0
        self.conv_even_padding_1 = 1
        self.conv_even_padding_2 = 2

        

        self.conv_stride = 1
        self.conv_stride1 = 2

        self.n_filters2 = 16

        self.n_filters3 = 32

        self.n_filters4 = 128

        self.n_filters5 = 256

        

        self.n_filters6 = 512


        

        #Constants for the dense layer
        self.n_units = 512


        #Layers
        self.conv = nn.Conv2d(in_channels=3,
                           out_channels=self.n_filters,
                           kernel_size=self.conv_even_kernel1,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding_2)
  
        
        self.conv2 = nn.Conv2d(in_channels=self.n_filters,
                           out_channels=self.n_filters2,
                           kernel_size=self.conv_even_kernel,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding_2)
        self.conv22 = nn.Conv2d(in_channels=self.n_filters2,
                           out_channels=self.n_filters2,
                           kernel_size=self.conv_even_kernel,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding_2)
        


        self.conv3 = nn.Conv2d(in_channels=self.n_filters2,
                           out_channels=self.n_filters3,
                           kernel_size=self.conv_even_kernel,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding_2)
        
        self.conv33 = nn.Conv2d(in_channels=self.n_filters3,
                           out_channels=self.n_filters3,
                           kernel_size=self.conv_even_kernel,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding_2)
        
        
        self.conv4 = nn.Conv2d(in_channels=self.n_filters3,
                           out_channels=self.n_filters4,
                           kernel_size=self.conv_even_kernel,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding_1)
        self.conv44 = nn.Conv2d(in_channels=self.n_filters4,
                           out_channels=self.n_filters4,
                           kernel_size=self.conv_even_kernel,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding_1)
        
        self.conv5 = nn.Conv2d(in_channels=self.n_filters4,
                           out_channels=self.n_filters5,
                           kernel_size=self.conv_even_kernel,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding_2)
        
        self.conv6 = nn.Conv2d(in_channels=self.n_filters5,
                           out_channels=self.n_filters6,
                           kernel_size=self.conv_even_kernel,
                           stride=self.conv_stride,
                           padding=self.conv_even_padding_1)



    def forward(self, x):
       # print(x.shape)
        x = self.conv(x)
       # print(x.shape)
        x = F.relu(x)
        x = self.conv2(x)
        x = F.relu(x)
        x = self.conv22(x)
      #  print(x.shape)
        
        x = F.max_pool2d(x, 3, 2)
      #  print(x.shape)
        x = F.relu(x)
        x = self.conv3(x)
    
      #  print(x.shape)
        
        x = F.relu(x)
        
        x = self.conv33(x)

        x = F.relu(x)

        x = F.max_pool2d(x, 3, 2)
       # print(x.shape)
        x = F.relu(x)
        #Resize for the dense 
        x = self.conv4(x)
        #print(x.shape)
      

        x = F.relu(x)
        #Resize for the dense 
        x = self.conv44(x)

        x = F.relu(x)

        x = F.max_pool2d(x, 3, 2)

        x = self.conv5(x)

        x = F.relu(x)

        x = F.max_pool2d(x, 3, 2)
      
        x = self.conv6(x)

        x = F.relu(x)

        return x



feature_mapping = Net()
if use_cuda:
    feature_mapping.cuda()
print(feature_mapping)
